# %%
import pandas as pd 
import numpy as np 

url = "https://raw.githubusercontent.com/KeithGalli/Regression-Example/master/insurance.csv"

df = pd.read_csv(url)
# Out:
# Running cells with 'end-to-end-ml-pipeline (Python 3.14.2)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'd:/end_to_end_ml_pipeline/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'
